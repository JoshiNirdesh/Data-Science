# %%
import pandas as pd 

data = {
    "name": ["Ram", "Sita", "Hari", "Gita", "John"],
    "age": [22, 19, 25, 17, 30],
    "city": ["Kathmandu", "Pokhara", "Kathmandu", "Lalitpur", "Bhaktapur"],
    "salary": [30000, 25000, 45000, 20000, 60000]
    
}

df = pd.DataFrame(data)

# %%
df
# Out:
#    name  age       city  salary
# 0   Ram   22  Kathmandu   30000
# 1  Sita   19    Pokhara   25000
# 2  Hari   25  Kathmandu   45000
# 3  Gita   17   Lalitpur   20000
# 4  John   30  Bhaktapur   60000

# %%
df.head(3)
# Out:
#    name  age       city  salary
# 0   Ram   22  Kathmandu   30000
# 1  Sita   19    Pokhara   25000
# 2  Hari   25  Kathmandu   45000

# %%
df.tail(2)
# Out:
#    name  age       city  salary
# 3  Gita   17   Lalitpur   20000
# 4  John   30  Bhaktapur   60000

# %%
df.shape
# Out:
# (5, 4)

# %%
df.columns
# Out:
# Index(['name', 'age', 'city', 'salary'], dtype='str')

# %%
df.dtypes
# Out:
# name        str
# age       int64
# city        str
# salary    int64
# dtype: object

# %%
df['name']
# Out:
# 0     Ram
# 1    Sita
# 2    Hari
# 3    Gita
# 4    John
# Name: name, dtype: str

# %%
df[['name','salary']]
# Out:
#    name  salary
# 0   Ram   30000
# 1  Sita   25000
# 2  Hari   45000
# 3  Gita   20000
# 4  John   60000

# %%
df[df['age']>20]
df[df['salary']>30000]['name']
# Out:
# 2    Hari
# 4    John
# Name: name, dtype: str

# %%
df[df['city']=="Kathmandu"]['name']
# Out:
# 0     Ram
# 2    Hari
# Name: name, dtype: str

# %%
df[(df['age']>20) & (df['age']<30)]
# Out:
#    name  age       city  salary
# 0   Ram   22  Kathmandu   30000
# 2  Hari   25  Kathmandu   45000

# %%
df.sort_values(by='salary' ,ascending=False)
# Out:
#    name  age       city  salary
# 4  John   30  Bhaktapur   60000
# 2  Hari   25  Kathmandu   45000
# 0   Ram   22  Kathmandu   30000
# 1  Sita   19    Pokhara   25000
# 3  Gita   17   Lalitpur   20000

# %%
df['salary'].mean()
# Out:
# 36000.0

# %%
df['salary'].max()
# Out:
# 60000

# %%
df['salary'].min()
# Out:
# 20000

# %%
df['salary'].sum()
# Out:
# 180000

# %%
df.groupby('city').size()
# Out:
# city
# Bhaktapur    1
# Kathmandu    2
# Lalitpur     1
# Pokhara      1
# dtype: int64
