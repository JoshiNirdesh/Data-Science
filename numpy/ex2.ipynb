# %%
import numpy as np
print("age,math,science")
data = np.array([[18,75,50],[16,80,70],[19,80,90],[20,95,94],[20,30,60]])
data.shape
age = data[0:,0]
np.average(age)
math = data[0:,1]
science = data[:,2]
science

# np.average(age)
# Out:
# age,math,science
# array([50, 70, 90, 94, 60])
