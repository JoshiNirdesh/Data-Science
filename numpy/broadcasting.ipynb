# %%
import numpy as np

# %%
arr = np.array([[10,20,30],[40,50,60],[70,80,90]])
dis = np.array([0.1,0.5,0.2])
arr
# Out:
# array([[10, 20, 30],
#        [40, 50, 60],
#        [70, 80, 90]])

# %%
price = arr - (arr*dis)
price
# Out:
# array([[ 9., 10., 24.],
#        [36., 25., 48.],
#        [63., 40., 72.]])
